# %% [markdown]
# # HR аналитика 👨‍💻

# %% [markdown]
# HR-аналитики компании «Работа с заботой» помогают бизнесу оптимизировать управление персоналом: бизнес предоставляет данные, а аналитики предлагают, как избежать финансовых потерь и оттока сотрудников. В этом HR-аналитикам пригодится машинное обучение, с помощью которого получится быстрее и точнее отвечать на вопросы бизнеса.
#
# Компания предоставила данные с характеристиками сотрудников компании. Среди них — уровень удовлетворённости сотрудника работой в компании. Эту информацию получили из форм обратной связи: сотрудники заполняют тест-опросник, и по его результатам рассчитывается доля их удовлетворённости от 0 до 1, где 0 — совершенно неудовлетворён, 1 — полностью удовлетворён.
#
# В рамках проекта требуется решить 2 задачи:
# Первая — построить модель, которая сможет предсказать уровень удовлетворённости сотрудника на основе данных заказчика.
# Почему бизнесу это важно: удовлетворённость работой напрямую влияет на отток сотрудников. А предсказание оттока — одна из важнейших задач HR-аналитиков. Внезапные увольнения несут в себе риски для компании, особенно если уходит важный сотрудник.
#
# Ваша вторая задача — построить модель, которая сможет на основе данных заказчика предсказать то, что сотрудник уволится из компании.

# %% [markdown]
# **Содержание**<a id='toc0_'></a>
# 1. [Подготовка                 ](#toc1_)
# 1.1. [Библиотеки                ](#toc1_1_)
# 1.2. [Конфигурация                ](#toc1_2_)
# 1.3. [Сервисные функции                ](#toc1_3_)
# 2. [Датасет `train` (train_job_satisfaction_rate.csv)                ](#toc2_)
# 2.1. [Загрузка                ](#toc2_1_)
# 2.2. [Проверка типов данных                ](#toc2_2_)
# 2.3. [Обработка дубликатов                ](#toc2_3_)
# 2.4. [Проверка пропусков                ](#toc2_4_)
# 2.5. [Изучение столбцов                ](#toc2_5_)
# 2.5.1. [Столбец `dept`                ](#toc2_5_1_)
# 2.5.2. [Столбец `level`                ](#toc2_5_2_)
# 2.5.3. [Столбец `workload`                ](#toc2_5_3_)
# 2.5.4. [Столбец `employment_years`                ](#toc2_5_4_)
# 2.5.5. [Столбец `last_year_promo`                ](#toc2_5_5_)
# 2.5.6. [Столбец `last_year_violations`                ](#toc2_5_6_)
# 2.5.7. [Столбец `supervisor_evaluation`                ](#toc2_5_7_)
# 2.5.8. [Столбец `salary`                ](#toc2_5_8_)
# 2.5.9. [Столбец `job_satisfaction_rate`                ](#toc2_5_9_)
# 2.6. [Вывод по датасету             ](#toc2_6_)
# 3. [Датасет `X_test` (test_features.csv)                ](#toc3_)
# 3.1. [Загрузка                ](#toc3_1_)
# 3.2. [Проверка типов данных                ](#toc3_2_)
# 3.3. [Обработка дубликатов                ](#toc3_3_)
# 3.4. [Проверка пропусков                ](#toc3_4_)
# 3.5. [Изучение столбцов                ](#toc3_5_)
# 3.5.1. [Столбец `dept`              ](#toc3_5_1_)
# 3.5.2. [Столбец `level`              ](#toc3_5_2_)
# 3.5.3. [Столбец `workload`              ](#toc3_5_3_)
# 3.5.4. [Столбец `employment_years`              ](#toc3_5_4_)
# 3.5.5. [Столбец `last_year_promo`              ](#toc3_5_5_)
# 3.5.6. [Столбец `last_year_violations`              ](#toc3_5_6_)
# 3.5.7. [Столбец `supervisor_evaluation`              ](#toc3_5_7_)
# 3.5.8. [Столбец `salary`              ](#toc3_5_8_)
# 3.6. [Вывод по датасету              ](#toc3_6_)
# 4. [Датасет `y_test` (test_target_job_satisfaction_rate.csv)                ](#toc4_)
# 4.1. [Загрузка               ](#toc4_1_)
# 4.2. [Проверка типов данных                ](#toc4_2_)
# 4.3. [Обработка дубликатов                ](#toc4_3_)
# 4.4. [Проверка пропусков                ](#toc4_4_)
# 4.5. [Изучение распределения                ](#toc4_5_)
# 4.6. [Вывод по датасету            ](#toc4_6_)
# 5. [Проверка корреляции                ](#toc5_)
# 5.1. [phik корреляция          ](#toc5_1_)
# 5.2. [Проверка мультиколлениарности           ](#toc5_2_)
# 5.3. [Выводы по корреляции           ](#toc5_3_)
# 6. [Предобработка и модели                ](#toc6_)
# 6.1. [Разделение данных                ](#toc6_1_)
# 6.2. [Пайплайны                ](#toc6_2_)
# 6.3. [Анализ остатков         ](#toc6_3_)
# 6.4. [Выводы по модели         ](#toc6_4_)
# 7. [Анализ важности признаков                ](#toc7_)
# 8. [Датасет `train2` ()               ](#toc8_)
# 8.1. [Загрузка              ](#toc8_1_)
# 8.2. [Проверка типов данных               ](#toc8_2_)
# 8.3. [Обработка дубликатов               ](#toc8_3_)
# 8.4. [Проверка пропусков               ](#toc8_4_)
# 8.5. [Выделение целевого признака               ](#toc8_5_)
# 8.6. [Кодирование целевого признака               ](#toc8_6_)
# 8.7. [Изучение столбцов         ](#toc8_7_)
# 8.7.1. [Столбец `dept`         ](#toc8_7_1_)
# 8.7.2. [Столбец `level`         ](#toc8_7_2_)
# 8.7.3. [Столбец `workload`         ](#toc8_7_3_)
# 8.7.4. [Столбец `employment_years`         ](#toc8_7_4_)
# 8.7.5. [Столбец `last_year_promo`         ](#toc8_7_5_)
# 8.7.6. [Столбец `last_year_violations`         ](#toc8_7_6_)
# 8.7.7. [Столбец `supervisor_evaluation`         ](#toc8_7_7_)
# 8.7.8. [Столбец `salary`         ](#toc8_7_8_)
# 8.7.9. [Столбец `quit`         ](#toc8_7_9_)
# 8.8. [Выводы по датасету         ](#toc8_8_)
# 9. [Датасет `y_test2` (test_target_quit.csv)               ](#toc9_)
# 9.1. [Загрузка               ](#toc9_1_)
# 9.2. [Проверка типов данных               ](#toc9_2_)
# 9.3. [Обработка дубликатов               ](#toc9_3_)
# 9.4. [Проверка пропусков               ](#toc9_4_)
# 9.5. [Изучение распределения               ](#toc9_5_)
# 9.6. [Кодирование целевого признака              ](#toc9_6_)
# 9.7. [Выводы по датасету        ](#toc9_7_)
# 10. [Исследовательский анализ данных               ](#toc10_)
# 10.1. [Изучение       ](#toc10_1_)
# 10.2. [Вывод      ](#toc10_2_)
# 11. [Добавление нового признака      ](#toc11_)
# 12. [Пайплайны и модели      ](#toc12_)
# 12.1. [Пайплайны ](#toc12_1_)
# 12.2. [Модели ](#toc12_2_)
# 12.3. [Вывод  ](#toc12_3_)
# 13. [Улучшение модели     ](#toc13_)
# 13.1. [Удаление столбца   ](#toc13_1_)
# 13.2. [ADASYN     ](#toc13_2_)
# 13.3. [SMOTE     ](#toc13_3_)
# 13.4. [Вывод    ](#toc13_4_)
# 14. [Общий вывод     ](#toc14_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=true
# 	anchor=true
# 	flat=true
# 	minLevel=2
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %% [markdown]
# ## 1. <a id='toc1_'></a>Подготовка                  [&#8593;](#toc0_)

# %% [markdown]
# ### 1.1. <a id='toc1_1_'></a>Библиотеки                 [&#8593;](#toc0_)

# %%
from IPython.display import clear_output

# %%
from platform import python_version
version = python_version()

if version.startswith('3.9'):  
    pass
    # %pip install --force-reinstall -v "numpy==1.22.4" -q
else: 
    pass
    # %pip install --upgrade numpy -q   

# %pip install --force-reinstall -v "matplotlib==3.8.0" -q

# %pip install --upgrade phik -q
# %pip install --upgrade prettytable -q
# %pip install --upgrade termcolor -q
# %pip install --upgrade seaborn -q
# %pip install --upgrade pandas -q
# %pip install --upgrade statsmodels -q
# %pip install --upgrade scikit-learn -q
# %pip install --upgrade shap -q
# %pip install --upgrade imbalanced-learn -q
# %pip install --upgrade optuna -q

clear_output()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import shap  # this import IS accessed

from os.path import exists
from imblearn.over_sampling  import (
    ADASYN,
    SMOTE)

# preprocessing
from sklearn.model_selection import (
    GridSearchCV,
    RandomizedSearchCV)
from sklearn.preprocessing import (
    MinMaxScaler,
    StandardScaler,
    OneHotEncoder,
    OrdinalEncoder,
    LabelEncoder)
from sklearn.impute import (
    KNNImputer,
    SimpleImputer)
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer


# models
from sklearn.linear_model import (
    LinearRegression,
    LogisticRegression)
from sklearn.svm import (
    SVR,
    SVC)
from sklearn.neighbors import (
    KNeighborsRegressor,
    KNeighborsClassifier)
from sklearn.tree import (
    DecisionTreeRegressor,
    DecisionTreeClassifier)
from sklearn.ensemble import (
    RandomForestRegressor,
    RandomForestClassifier)

# metrics
from sklearn.metrics import (
    roc_auc_score,
    make_scorer,
    ConfusionMatrixDisplay)

from sklearn.inspection import permutation_importance
from phik import phik_matrix  # this import IS accessed
from prettytable import PrettyTable
from termcolor import colored
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant

# %% [markdown]
# ### 1.2. <a id='toc1_2_'></a>Конфигурация                 [&#8593;](#toc0_)

# %%
RANDOM_STATE = 27
TEST_SIZE = 0.2


pd.options.display.float_format = '{:.2f}'.format
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ### 1.3. <a id='toc1_3_'></a>Сервисные функции                 [&#8593;](#toc0_)

# %%
def print_table_about_nans(data: pd.DataFrame) -> None:
    table = PrettyTable()
    table.field_names = ['Feature', 'Missing values count']
    
    missing_info = data.isna().sum().sort_values()
    cols = missing_info.index.to_list()
    for col in cols:
        count = missing_info[col]
        color = 'green' if count == 0 else 'red'
        s = f'{count} ({count / len(data):.2%})'
        table.add_row([col, colored(s, color)])
    
    print(table)

# %%
def draw_plots_about_column(df: pd.DataFrame,
                            column: str,
                            column_description: str,
                            bins: int = 20
                            ) -> None:
    _, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(12, 10))
    
    sns.violinplot(df, x=column, ax=ax1, orient='h')
    ax1.set_xlabel(column_description)
    ax1.grid()
    
    sns.boxplot(df, x=column, ax=ax2)
    ax2.set_xlabel(column_description)
    ax2.grid()
    
    sns.histplot(df, x=column, bins=bins, ax=ax3)
    ax3.set_xlabel(column_description)
    ax3.grid()
    ax3.set_ylabel('Количество')
    
    ax4.set_visible(False)
    
    plt.suptitle(f'Информация о колонке `{column_description}`', fontsize=18)
    plt.tight_layout()

    plt.show()

# %%
def plot_pie_chart(series: pd.Series) -> None:
    _table = series.value_counts()
    data, labels = _table.values, _table.index
    plt.pie(data, labels=labels, autopct='%.0f%%')
    plt.title(f'Распределение в столбце `{series.name}`')
    plt.show()

# %%
def get_dataframe(paths: list[str]) -> pd.DataFrame:
    for _path in paths:
        if not exists(_path) and not _path.startswith('http'):
            continue
        
        try:
            df = pd.read_csv(_path)
        except:
            continue
        
        if df is None:
            continue
        
        return df
    
    raise FileNotFoundError('No paths are valid and/or for correct csv file.')

# %%
def smape_function(y_true: np.ndarray, y_pred: np.ndarray) -> float:    
    return np.mean(np.abs(y_true - y_pred) / ((np.abs(y_true) + np.abs(y_pred)) / 2)) * 100

smape = make_scorer(smape_function, greater_is_better=False)

# %%
def get_plots_about_residuals(y_true: np.array, y_pred: np.array) -> None:
    res = y_true - y_pred
    
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 5))
    
    sns.histplot(res, ax=ax1)
    ax1.set_xlabel('Остатки')
    ax1.set_ylabel('Количество')
    ax1.axvline(x=0, color='green', lw=3, ls='-', label='Нулевое значение')
    ax1.axvline(x=res.mean(), color='red', lw=3, ls='--', label='Среднее значение остатков')
    ax1.legend()
    
    sns.scatterplot(x=y_pred, y=res, ax=ax2)
    ax2.set_xlabel('Предсказанные значение')
    ax2.set_ylabel('Остатки')
    
    fig.suptitle('Информация об остатках')

# %%
def draw_pair_pie_plot(
    first_df: pd.DataFrame,
    first_df_name: str,
    second_df: pd.DataFrame,
    second_df_name: str,
    col: str
    ) -> None:
    
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))
    
    table1 = first_df[col].value_counts()
    data, labels = table1.values, table1.index
    ax1.pie(data, labels=labels, autopct='%.0f%%')
    ax1.set_title(f'Датафрейм `{first_df_name}`')
    
    table2 = second_df[col].value_counts()
    data, labels = table2.values, table2.index
    ax2.pie(data, labels=labels, autopct='%.0f%%')
    ax2.set_title(f'Датафрейм `{second_df_name}`')
    
    fig.suptitle(f'Распределение в столбце `{col}`')
    plt.show()

# %% [markdown]
# ## 2. <a id='toc2_'></a>Датасет `train` (train_job_satisfaction_rate.csv)                 [&#8593;](#toc0_)

# %% [markdown]
# ### 2.1. <a id='toc2_1_'></a>Загрузка                 [&#8593;](#toc0_)

# %%
# data is not presented due to copyright
train = get_dataframe(['data/train.csv'])

# %%
train.head()
# Out:
#        id        dept   level workload  employment_years last_year_promo  \
# 0  155278       sales  junior   medium                 2              no
# 1  653870          hr  junior     high                 2              no
# 2  184592       sales  junior      low                 1              no
# 3  171431  technology  junior      low                 4              no
# 4  693419          hr  junior   medium                 1              no
#
#   last_year_violations  supervisor_evaluation  salary  job_satisfaction_rate
# 0                   no                      1   24000                   0.58
# 1                   no                      5   38400                   0.76
# 2                   no                      2   12000                   0.11
# 3                   no                      2   18000                   0.37
# 4                   no                      3   22800                   0.20

# %% [markdown]
# ### 2.2. <a id='toc2_2_'></a>Проверка типов данных                 [&#8593;](#toc0_)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     4000 non-null   int64
#  1   dept                   3994 non-null   object
#  2   level                  3996 non-null   object
#  3   workload               4000 non-null   object
#  4   employment_years       4000 non-null   int64
#  5   last_year_promo        4000 non-null   object
#  6   last_year_violations   4000 non-null   object
#  7   supervisor_evaluation  4000 non-null   int64
#  8   salary                 4000 non-null   int64
#  9   job_satisfaction_rate  4000 non-null   float64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 312.6+ KB

# %% [markdown]
# Типы данных указаны верно во всех столбцах.

# %% [markdown]
# ### 2.3. <a id='toc2_3_'></a>Обработка дубликатов                 [&#8593;](#toc0_)

# %%
train.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Дубликатов в датасете нет, следовательно можно установить столбец `id` в качестве индекса. Сразу же отсортируем датасет по индексу.

# %%
train = train.set_index('id').sort_index()

# %%
train.head()
# Out:
#               dept   level workload  employment_years last_year_promo  \
# id
# 100954  purchasing  junior      low                 1              no
# 101057       sales  junior      low                 1              no
# 101074       sales  junior   medium                 2              no
# 101081       sales  middle      low                 2              no
# 101129  technology  junior   medium                 1              no
#
#        last_year_violations  supervisor_evaluation  salary  \
# id
# 100954                   no                      4   15600
# 101057                  yes                      4   19200
# 101074                   no                      2   20400
# 101081                   no                      4   28800
# 101129                   no                      4   34800
#
#         job_satisfaction_rate
# id
# 100954                   0.60
# 101057                   0.45
# 101074                   0.36
# 101081                   0.66
# ...

# %% [markdown]
# Проверим еще раз, не появились ли полные дубликаты, после удаления id. И при наличии удалим.

# %%
train.duplicated().sum()
# Out:
# 245

# %%
train = train.drop_duplicates()

# %%
train.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### 2.4. <a id='toc2_4_'></a>Проверка пропусков                 [&#8593;](#toc0_)

# %%
print_table_about_nans(train)
# Out:
# +-----------------------+----------------------+
# |        Feature        | Missing values count |
# +-----------------------+----------------------+
# |        workload       |      0 (0.00%)       |
# |    employment_years   |      0 (0.00%)       |
# |    last_year_promo    |      0 (0.00%)       |
# |  last_year_violations |      0 (0.00%)       |
# | supervisor_evaluation |      0 (0.00%)       |
# |         salary        |      0 (0.00%)       |
# | job_satisfaction_rate |      0 (0.00%)       |
# |         level         |      4 (0.11%)       |
# |          dept         |      6 (0.16%)       |
# +-----------------------+----------------------+

# %%
_mask = (train['level'].isna()) | (train['dept'].isna())
_mask.sum()
# Out:
# 10

# %%
train[_mask]
# Out:
#          dept   level workload  employment_years last_year_promo  \
# id
# 135043  sales     NaN   medium                 1              no
# 168668    NaN  junior      low                 3              no
# 416327  sales     NaN      low                 1              no
# 475114    NaN  junior     high                 4              no
# 497243    NaN  junior   medium                 1              no
# 631073  sales     NaN   medium                 1              no
# 641150    NaN  junior      low                 3              no
# 694746    NaN  junior   medium                 5              no
# 814624    NaN  junior   medium                 3              no
# 998838  sales     NaN   medium                 1              no
#
#        last_year_violations  supervisor_evaluation  salary  \
# id
# 135043                   no                      3   26400
# 168668                   no                      4   18000
# 416327                   no                      5   18000
# ...

# %% [markdown]
# Обнаружено 10 строк с пропусками в столбце `dept` или `level`. Заполним эти пропуски далее в пайплайне.

# %% [markdown]
# ### 2.5. <a id='toc2_5_'></a>Изучение столбцов                 [&#8593;](#toc0_)

# %% [markdown]
# #### 2.5.1. <a id='toc2_5_1_'></a>Столбец `dept`                 [&#8593;](#toc0_)

# %%
train['dept'].value_counts()
# Out:
# dept
# sales         1374
# technology     818
# purchasing     586
# marketing      531
# hr             440
# Name: count, dtype: int64

# %%
plot_pie_chart(train['dept'])

# %% [markdown]
# #### 2.5.2. <a id='toc2_5_2_'></a>Столбец `level`                 [&#8593;](#toc0_)

# %%
train['level'].value_counts()
# Out:
# level
# junior    1699
# middle    1695
# sinior     357
# Name: count, dtype: int64

# %%
plot_pie_chart(train['level'])

# %% [markdown]
# #### 2.5.3. <a id='toc2_5_3_'></a>Столбец `workload`                 [&#8593;](#toc0_)

# %%
train['workload'].value_counts()
# Out:
# workload
# medium    1908
# low       1125
# high       722
# Name: count, dtype: int64

# %%
plot_pie_chart(train['workload'])

# %% [markdown]
# #### 2.5.4. <a id='toc2_5_4_'></a>Столбец `employment_years`                 [&#8593;](#toc0_)

# %%
train['employment_years'].value_counts()
# Out:
# employment_years
# 1     852
# 2     718
# 3     458
# 4     372
# 5     371
# 7     291
# 6     282
# 8     191
# 9     129
# 10     91
# Name: count, dtype: int64

# %%
draw_plots_about_column(train, 'employment_years', 'Кол-во лет в компании', bins=10)

# %% [markdown]
# #### 2.5.5. <a id='toc2_5_5_'></a>Столбец `last_year_promo`                 [&#8593;](#toc0_)

# %%
train['last_year_promo'].value_counts()
# Out:
# last_year_promo
# no     3635
# yes     120
# Name: count, dtype: int64

# %%
plot_pie_chart(train['last_year_promo'])

# %% [markdown]
# #### 2.5.6. <a id='toc2_5_6_'></a>Столбец `last_year_violations`                 [&#8593;](#toc0_)

# %%
train['last_year_violations'].value_counts()
# Out:
# last_year_violations
# no     3202
# yes     553
# Name: count, dtype: int64

# %%
plot_pie_chart(train['last_year_violations'])

# %% [markdown]
# #### 2.5.7. <a id='toc2_5_7_'></a>Столбец `supervisor_evaluation`                 [&#8593;](#toc0_)

# %%
train['supervisor_evaluation'].value_counts()
# Out:
# supervisor_evaluation
# 4    1451
# 3    1190
# 5     534
# 2     382
# 1     198
# Name: count, dtype: int64

# %%
draw_plots_about_column(train, 'supervisor_evaluation', 'Оценка руководителя', bins=5)

# %% [markdown]
# #### 2.5.8. <a id='toc2_5_8_'></a>Столбец `salary`                 [&#8593;](#toc0_)

# %%
draw_plots_about_column(train, 'salary', 'Заплата')

# %% [markdown]
# #### 2.5.9. <a id='toc2_5_9_'></a>Столбец `job_satisfaction_rate`                 [&#8593;](#toc0_)

# %%
draw_plots_about_column(train, 'job_satisfaction_rate',  'Уровень удовлетворенности')

# %% [markdown]
# ### 2.6. <a id='toc2_6_'></a>Вывод по датасету              [&#8593;](#toc0_)

# %% [markdown]
# Тренировочный датасет содержит различную информацию о сотрудниках. Полных дубликатов нет. Однако есть 10 строк с пропущенным значения в столбцах `dept` или `level`. Данные пропуски будут заполнены в пайплайне. Столбцы содержат информацию разного типа: категориальные (как номинальные, так и порядковые) и числовые.
#
# Целевой признак имеет околонормальное распределение со смещением вправо.

# %% [markdown]
# ## 3. <a id='toc3_'></a>Датасет `X_test` (test_features.csv)                 [&#8593;](#toc0_)

# %% [markdown]
# ### 3.1. <a id='toc3_1_'></a>Загрузка                 [&#8593;](#toc0_)

# %%
# data is not presented due to copyright
X_test = get_dataframe(['data/X_test.csv'])

# %%
X_test.head()
# Out:
#        id       dept   level workload  employment_years last_year_promo  \
# 0  485046  marketing  junior   medium                 2              no
# 1  686555         hr  junior   medium                 1              no
# 2  467458      sales  middle      low                 5              no
# 3  418655      sales  middle      low                 6              no
# 4  789145         hr  middle   medium                 5              no
#
#   last_year_violations  supervisor_evaluation  salary
# 0                   no                      5   28800
# 1                   no                      4   30000
# 2                   no                      4   19200
# 3                   no                      4   19200
# 4                   no                      5   40800

# %% [markdown]
# ### 3.2. <a id='toc3_2_'></a>Проверка типов данных                 [&#8593;](#toc0_)

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2000 non-null   int64
#  1   dept                   1998 non-null   object
#  2   level                  1999 non-null   object
#  3   workload               2000 non-null   object
#  4   employment_years       2000 non-null   int64
#  5   last_year_promo        2000 non-null   object
#  6   last_year_violations   2000 non-null   object
#  7   supervisor_evaluation  2000 non-null   int64
#  8   salary                 2000 non-null   int64
# dtypes: int64(4), object(5)
# memory usage: 140.8+ KB

# %% [markdown]
# ### 3.3. <a id='toc3_3_'></a>Обработка дубликатов                 [&#8593;](#toc0_)

# %%
X_test.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Дубликатов в датасете нет, следовательно можно установить столбец `id` в качестве индекса. Сразу же отсортируем датасет по индексу.

# %%
X_test = X_test.set_index('id').sort_index()
X_test.head()
# Out:
#               dept   level workload  employment_years last_year_promo  \
# id
# 100298          hr  junior      low                 2              no
# 100480   marketing  junior      low                 4              no
# 100503  purchasing  middle     high                 5              no
# 100610       sales  middle   medium                 5              no
# 100692       sales  middle     high                 6              no
#
#        last_year_violations  supervisor_evaluation  salary
# id
# 100298                   no                      4   19200
# 100480                   no                      4   16800
# 100503                   no                      4   55200
# 100610                   no                      4   43200
# 100692                   no                      4   48000

# %% [markdown]
# ### 3.4. <a id='toc3_4_'></a>Проверка пропусков                 [&#8593;](#toc0_)

# %%
print_table_about_nans(X_test)
# Out:
# +-----------------------+----------------------+
# |        Feature        | Missing values count |
# +-----------------------+----------------------+
# |        workload       |      0 (0.00%)       |
# |    employment_years   |      0 (0.00%)       |
# |    last_year_promo    |      0 (0.00%)       |
# |  last_year_violations |      0 (0.00%)       |
# | supervisor_evaluation |      0 (0.00%)       |
# |         salary        |      0 (0.00%)       |
# |         level         |      1 (0.05%)       |
# |          dept         |      2 (0.10%)       |
# +-----------------------+----------------------+

# %%
_mask = (X_test['dept'].isna()) | (X_test['level']).isna()
_mask.sum()
# Out:
# 3

# %%
X_test[_mask]
# Out:
#          dept   level workload  employment_years last_year_promo  \
# id
# 471990  sales     NaN      low                 1              no
# 609865    NaN  junior   medium                 1              no
# 832342    NaN  junior   medium                 1              no
#
#        last_year_violations  supervisor_evaluation  salary
# id
# 471990                   no                      3   12000
# 609865                   no                      1   20400
# 832342                   no                      4   28800

# %% [markdown]
# Как и в тренировочном датасете видим неcколько строк (в данном случае 3) с пропусками. Их заполнение будет происходить тоже в пайплайне предобработки.

# %% [markdown]
# ### 3.5. <a id='toc3_5_'></a>Изучение столбцов                 [&#8593;](#toc0_)

# %% [markdown]
# #### 3.5.1. <a id='toc3_5_1_'></a>Столбец `dept`               [&#8593;](#toc0_)

# %%
X_test['dept'].value_counts()
# Out:
# dept
# sales         763
# technology    455
# marketing     279
# purchasing    273
# hr            227
#                 1
# Name: count, dtype: int64

# %% [markdown]
# Видим, что одно значений пустое, скорее всего пробел(ы). Найдем его и изучим дополнительно.

# %%
_mask = X_test['dept'].str.match(r'\W+', na=False)
X_test[_mask]
# Out:
#        dept   level workload  employment_years last_year_promo  \
# id
# 822186       middle   medium                 3              no
#
#        last_year_violations  supervisor_evaluation  salary
# id
# 822186                   no                      4   38400

# %% [markdown]
# Видим, пропущенное значение. Проверим, что за значение.

# %%
X_test.loc[822186, 'dept']
# Out:
# ' '

# %% [markdown]
# Данное значение будет обработано в пайплайне.

# %%
plot_pie_chart(X_test['dept'])

# %% [markdown]
# #### 3.5.2. <a id='toc3_5_2_'></a>Столбец `level`               [&#8593;](#toc0_)

# %%
X_test['level'].value_counts()
# Out:
# level
# junior    974
# middle    854
# sinior    171
# Name: count, dtype: int64

# %%
plot_pie_chart(X_test['level'])

# %% [markdown]
# #### 3.5.3. <a id='toc3_5_3_'></a>Столбец `workload`               [&#8593;](#toc0_)

# %%
X_test['workload'].value_counts()
# Out:
# workload
# medium    1043
# low        593
# high       363
#              1
# Name: count, dtype: int64

# %% [markdown]
# Здесь также наблюдается пустое значение. Изучим его тоже дополнительно.

# %%
_mask = X_test['workload'].str.match(r'\W+', na=False)
X_test[_mask]
# Out:
#              dept   level workload  employment_years last_year_promo  \
# id
# 590867  marketing  junior                          4              no
#
#        last_year_violations  supervisor_evaluation  salary
# id
# 590867                   no                      4   28800

# %% [markdown]
# Проверим данное значение

# %%
X_test.loc[590867, 'workload']
# Out:
# ' '

# %%
plot_pie_chart(X_test['workload'])

# %% [markdown]
# #### 3.5.4. <a id='toc3_5_4_'></a>Столбец `employment_years`               [&#8593;](#toc0_)

# %%
X_test['employment_years'].value_counts()
# Out:
# employment_years
# 1     522
# 2     374
# 3     234
# 4     187
# 5     179
# 7     174
# 6     138
# 8      91
# 9      66
# 10     35
# Name: count, dtype: int64

# %%
draw_plots_about_column(X_test, 'employment_years', 'employment_years', bins=10)

# %% [markdown]
# #### 3.5.5. <a id='toc3_5_5_'></a>Столбец `last_year_promo`               [&#8593;](#toc0_)

# %%
X_test['last_year_promo'].value_counts()
# Out:
# last_year_promo
# no     1937
# yes      63
# Name: count, dtype: int64

# %%
plot_pie_chart(X_test['last_year_promo'])

# %% [markdown]
# #### 3.5.6. <a id='toc3_5_6_'></a>Столбец `last_year_violations`               [&#8593;](#toc0_)

# %%
X_test['last_year_violations'].value_counts()
# Out:
# last_year_violations
# no     1738
# yes     262
# Name: count, dtype: int64

# %%
plot_pie_chart(X_test['last_year_violations'])

# %% [markdown]
# #### 3.5.7. <a id='toc3_5_7_'></a>Столбец `supervisor_evaluation`               [&#8593;](#toc0_)

# %%
X_test['supervisor_evaluation'].value_counts()
# Out:
# supervisor_evaluation
# 4    857
# 3    575
# 5    284
# 2    196
# 1     88
# Name: count, dtype: int64

# %%
draw_plots_about_column(X_test, 'supervisor_evaluation', 'supervisor_evaluation', bins=5)

# %% [markdown]
# #### 3.5.8. <a id='toc3_5_8_'></a>Столбец `salary`               [&#8593;](#toc0_)

# %%
draw_plots_about_column(X_test, 'salary', 'salary')

# %% [markdown]
# ### 3.6. <a id='toc3_6_'></a>Вывод по датасету               [&#8593;](#toc0_)

# %% [markdown]
# Тестовый датасет по своему содержанию похож на тренировочный. В столбцах `dept` и `level` было по 1 пустому значению. Они, как и все остальные пропуски, будут обработаны в пайплайне.

# %% [markdown]
# ## 4. <a id='toc4_'></a>Датасет `y_test` (test_target_job_satisfaction_rate.csv)                 [&#8593;](#toc0_)

# %% [markdown]
# ### 4.1. <a id='toc4_1_'></a>Загрузка                [&#8593;](#toc0_)

# %%
# data is not presented due to copyright
y_test = get_dataframe(['data/y_test.csv'])

# %%
y_test.head()
# Out:
#        id  job_satisfaction_rate
# 0  130604                   0.74
# 1  825977                   0.75
# 2  418490                   0.60
# 3  555320                   0.72
# 4  826430                   0.08

# %% [markdown]
# ### 4.2. <a id='toc4_2_'></a>Проверка типов данных                 [&#8593;](#toc0_)

# %%
y_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     2000 non-null   int64
#  1   job_satisfaction_rate  2000 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 31.4 KB

# %% [markdown]
# ### 4.3. <a id='toc4_3_'></a>Обработка дубликатов                 [&#8593;](#toc0_)

# %%
y_test.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Дубликатов в датасете нет, следовательно можно установить столбец `id` в качестве индекса. Сразу же отсортируем датасет по индексу и возьмем только нужный столбец, чтобы работать с серией.

# %%
y_test = y_test.set_index('id').sort_index()['job_satisfaction_rate']
y_test[:5]
# Out:
# id
# 100298   0.80
# 100480   0.84
# 100503   0.79
# 100610   0.75
# 100692   0.69
# Name: job_satisfaction_rate, dtype: float64

# %% [markdown]
# ### 4.4. <a id='toc4_4_'></a>Проверка пропусков                 [&#8593;](#toc0_)

# %%
y_test.isna().sum()
# Out:
# 0

# %% [markdown]
# ### 4.5. <a id='toc4_5_'></a>Изучение распределения                 [&#8593;](#toc0_)

# %%
sns.histplot(y_test)
plt.xlabel('Значения целевого признака')
plt.ylabel('Раз встретилось')
plt.title('Гистограмма целевого признака')
plt.grid()
plt.show()

# %% [markdown]
# ### 4.6. <a id='toc4_6_'></a>Вывод по датасету             [&#8593;](#toc0_)

# %% [markdown]
# Данный датасет содержит только целевой признак для тестового датасета. Его распределение примерно похоже на распределение в тренировочном датасете. Пропуски и полные дубликаты отсутствуют. Для удобства датасет был преобразован в серию (pd.Series).

# %% [markdown]
# ## 5. <a id='toc5_'></a>Проверка корреляции                 [&#8593;](#toc0_)

# %%
target = 'job_satisfaction_rate'

num_cols = [
    'employment_years',
    'supervisor_evaluation',
    'salary'
]

ohe_cols = [
    'dept'
]

ord_cols = [
    'level',
    'workload',
    'last_year_promo',
    'last_year_violations'
]

# %% [markdown]
# ### 5.1. <a id='toc5_1_'></a>phik корреляция           [&#8593;](#toc0_)

# %%
plt.figure(figsize=(20, 10))
sns.heatmap(train.phik_matrix(interval_cols=num_cols + [target]),
            cmap='Greens',
            annot=True,
            fmt='.2f');

plt.title(r'$phi_k$ корреляция между всеми признаками', fontsize=18);

# %% [markdown]
# ### 5.2. <a id='toc5_2_'></a>Проверка мультиколлениарности            [&#8593;](#toc0_)

# %%
scaler = StandardScaler()
df_for_vif = pd.DataFrame(scaler.fit_transform(train[num_cols]), columns=num_cols)

with_constants = add_constant(df_for_vif)

vif_data = pd.DataFrame()
vif_data["Variable"] = with_constants.columns
vif_data["VIF"] = [variance_inflation_factor(with_constants.values, i) for i in range(with_constants.shape[1])]

vif_data.sort_values(by='VIF')
# Out:
#                 Variable  VIF
# 0                  const 1.00
# 2  supervisor_evaluation 1.00
# 1       employment_years 1.26
# 3                 salary 1.26

# %% [markdown]
# ### 5.3. <a id='toc5_3_'></a>Выводы по корреляции            [&#8593;](#toc0_)

# %% [markdown]
# - Целевой признак имеет сильную корреляцию с признаком `supervisor_evaluation` (оценка руководителя).
# - Наблюдается умеренная корреляция с признаком `last_year_violations` (нарушения в прошлом году).
# - Слабая корреляция с признаком `employment_years` (сколько лет в компании).
# - Со всеми остальными признаками не наблюдается почти никакой корреляции.
# - Среди числовых признаков не наблюдается мультиколлинеарности.

# %% [markdown]
# ## 6. <a id='toc6_'></a>Предобработка и модели                 [&#8593;](#toc0_)

# %% [markdown]
# ### 6.1. <a id='toc6_1_'></a>Разделение данных                 [&#8593;](#toc0_)

# %%
X_train = train.drop(target, axis=1)
y_train = train[target]

# %% [markdown]
# ### 6.2. <a id='toc6_2_'></a>Пайплайны                 [&#8593;](#toc0_)

# %%
ohe_pipeline = Pipeline(
    [
        (
            'SimpleImputer_before_ohe_1',
            SimpleImputer(strategy='most_frequent', missing_values=np.nan)
        ),
        (
            'SimpleImputer_before_ohe_2',
            SimpleImputer(strategy='most_frequent', missing_values=' ')
        ),
        (
            'ohe',
            OneHotEncoder(drop='first', handle_unknown='ignore', sparse_output=False)
        )
    ]
)

# %%
ord_pipeline = Pipeline(
    [
        (
            'SimpleImputer_before_ord_1',
            SimpleImputer(strategy='most_frequent', missing_values=np.nan)
        ),
        (
            'SimpleImputer_before_ord_2',
            SimpleImputer(strategy='most_frequent', missing_values=' ')
        ),
        (
            'ord',
            OrdinalEncoder(
                categories=[
                    ['junior', 'middle', 'sinior'],
                    ['low', 'medium', 'high'],
                    ['no', 'yes'],
                    ['no', 'yes']
                ],
                unknown_value=np.nan,
                handle_unknown='use_encoded_value'
            )
        ),
        (
            'SimpleImputer_after_ord',
            SimpleImputer(strategy='most_frequent', missing_values=np.nan)
        ),
    ]
)

# %%
data_preprocessor = ColumnTransformer(
    [
        ('ohe', ohe_pipeline, ohe_cols),
        ('ord', ord_pipeline, ord_cols),
        ('num', MinMaxScaler(), num_cols)
    ],
    remainder='passthrough'
)

# %%
final_pipeline = Pipeline(
    [
        ('preprocessor', data_preprocessor),
        ('models', DecisionTreeRegressor(random_state=RANDOM_STATE))
    ]
)

# %%
final_pipeline
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('SimpleImputer_before_ohe_1',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('SimpleImputer_before_ohe_2',
#                                                                    SimpleImputer(missing_values=' ',
#                                                                                  strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
# ...

# %% [markdown]
# ---

# %%
param_grid = [
    {
        'models': [DecisionTreeRegressor(random_state=RANDOM_STATE)],
        'models__max_depth': range(2,  5),
        'models__max_features': range(2, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    },
    {
        'models': [KNeighborsRegressor(n_jobs=-1)],
        'models__n_neighbors': range(2, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    },
    {
        'models': [LinearRegression(n_jobs=-1)],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    },
    {
        'models': [SVR()],
        'models__C': [0.01, 0.1, 1, 10, 100],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    },
    {
        'models': [RandomForestRegressor(random_state=RANDOM_STATE, n_jobs=-1)],
        'models__n_estimators': [100, 500, 1000],
        'models__min_samples_split': [2, 4],
        'models__min_samples_leaf': [1, 3],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    }
]

# %% [markdown]
# ---

# %%
grid = GridSearchCV(
    final_pipeline,
    param_grid=param_grid,
    scoring=smape,
)

# %%
# %%time
grid.fit(X_train, y_train);
# Out:
# CPU times: user 6min 52s, sys: 28.3 s, total: 7min 21s
# Wall time: 2min 5s

# %%
round(grid.best_score_, 2)
# Out:
# -13.66

# %%
grid.best_estimator_
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('SimpleImputer_before_ohe_1',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('SimpleImputer_before_ohe_2',
#                                                                    SimpleImputer(missing_values=' ',
#                                                                                  strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
# ...

# %%
pd.DataFrame(grid.cv_results_)[['rank_test_score', 'param_models', 'mean_test_score', 'params']].sort_values(by='rank_test_score')
# Out:
#     rank_test_score                                       param_models  \
# 70                1  RandomForestRegressor(n_jobs=-1, random_state=27)
# 69                2  RandomForestRegressor(n_jobs=-1, random_state=27)
# 71                3  RandomForestRegressor(n_jobs=-1, random_state=27)
# 67                4  RandomForestRegressor(n_jobs=-1, random_state=27)
# 61                5  RandomForestRegressor(n_jobs=-1, random_state=27)
# ..              ...                                                ...
# 6                84             DecisionTreeRegressor(random_state=27)
# 41               87                                              SVR()
# 5                88             DecisionTreeRegressor(random_state=27)
# 4                88             DecisionTreeRegressor(random_state=27)
# 3                88             DecisionTreeRegressor(random_state=27)
#
#     mean_test_score  \
# 70           -13.66
# 69           -13.67
# 71           -13.67
# 67           -13.68
# ...

# %%
y_pred = grid.predict(X_test)
round(smape_function(y_test, y_pred), 2)
# Out:
# 12.22

# %% [markdown]
# ### 6.3. <a id='toc6_3_'></a>Анализ остатков          [&#8593;](#toc0_)

# %%
get_plots_about_residuals(y_test, y_pred)

# %% [markdown]
# ### 6.4. <a id='toc6_4_'></a>Выводы по модели          [&#8593;](#toc0_)

# %% [markdown]
# Итоговый результат составил `12.22`, что меньше максимально допустумой метрики в `15`. Анализ остатков не выявил каких-то смещений в предсказаниях и/или неравномерности дисперсии. Следовательно модель неплохо справляется со своей задачей.

# %% [markdown]
# ## 7. <a id='toc7_'></a>Анализ важности признаков                 [&#8593;](#toc0_)

# %%
best_model = grid.best_estimator_.named_steps['models']

# %%
X_transformed = grid.best_estimator_.named_steps['preprocessor'].transform(X_train)

# %%
feature_names = grid.best_estimator_.named_steps['preprocessor'].get_feature_names_out()

# %%
# explainer = shap.Explainer(best_model, feature_names=feature_names)
# shap_values = explainer(X_transformed)

# shap.plots.beeswarm(shap_values, max_display=None)

# %% [markdown]
# Предыдущая ячейка работает очень долго, поэтому ниже представлен ее результат в виде изображения.
#
# ![результат SHAP анализа важности признаков](http://i.imgur.com/cxeLk6j.png)

# %% [markdown]
# **Выводы:**
# - Как и показала phik корреляция, признак `supervisor_evaluation` (оценка руководителя) имеет высокое влияние на целевой признак. Чем выше оценка - тем больше сотрудник удовлетворен работой. И наоборот: если оценка руководителя низкая - это показатель низкой удовлетстворенности сотрудника работой. Причем здесь, скорее всего, прослеживается обратная причинно-следственная связь. Если сотрудник не удовлетворен работой -> он не очень ответственно относится к своим задачам -> руководитель ставит ему низкую оценку.
# - Количество лет, которые сотрудник проработал в компании (признак `employment_years`) позитивно влияет на его удовлетворенность. Чем больше лет сотрудник работает в этой компании, тем более он удовлетворен. А вот сотрудники, кто работает в компании не так давно менее удовлетворены работой. Возможно, компании стоит присмотреться к новичкам. Например, пересмотреть их процесс адаптации, длительность испытательного срока и т.д.
# - Но парадоксально с предыдущим выводом имеет следующий факт. По большей части работой удовлетворены начинающие специалисты. И чем выше уровень специалиста (признак `level`), тем ниже уровень удовлетворенности. Компании стоит пересмотреть "плюшки" для опытных специалистов (особенно senior уровня).
# - Зарплата (столбец `salary`) имеет ожидаемо напрямую влияет на уровень удовлетворенности.
# - Уровень нагрузки (признак `workload`) подтверждает вывод № 3. Чем выше нагрузка - тем меньший уровень удовлетворенности у сотрудника. Возможно, компании стоит пересмотреть ЗП у сотрудников в высокой нагрузкой и/или награду за переработки.
# - Наличие нарушений в трудовом договоре (столбец `last_year_violations`) также напрямую влияет на целевой признак и скорее всего также (как и для признака `supervisor_evaluation`) имеет обратную причинно-следственную связь. Ведь если сотрудник нарушал трудовой друговор, значит его что-то не устраивает. Отсюда и невысокая удовлетворенность.

# %% [markdown]
# ---

# %% [markdown]
# ## 8. <a id='toc8_'></a>Датасет `train2` ()                [&#8593;](#toc0_)

# %% [markdown]
# ### 8.1. <a id='toc8_1_'></a>Загрузка               [&#8593;](#toc0_)

# %%
# data is not presented due to copyright
train2 = get_dataframe(['data/train2.csv'])

# %%
train2.head()
# Out:
#        id        dept   level workload  employment_years last_year_promo  \
# 0  723290       sales  middle     high                 2              no
# 1  814010       sales  junior   medium                 2              no
# 2  155091  purchasing  middle   medium                 5              no
# 3  257132       sales  junior   medium                 2              no
# 4  910140   marketing  junior   medium                 2              no
#
#   last_year_violations  supervisor_evaluation  salary quit
# 0                   no                      4   54000   no
# 1                   no                      4   27600   no
# 2                   no                      1   37200   no
# 3                  yes                      3   24000  yes
# 4                   no                      5   25200   no

# %% [markdown]
# ### 8.2. <a id='toc8_2_'></a>Проверка типов данных                [&#8593;](#toc0_)

# %%
train2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     4000 non-null   int64
#  1   dept                   4000 non-null   object
#  2   level                  4000 non-null   object
#  3   workload               4000 non-null   object
#  4   employment_years       4000 non-null   int64
#  5   last_year_promo        4000 non-null   object
#  6   last_year_violations   4000 non-null   object
#  7   supervisor_evaluation  4000 non-null   int64
#  8   salary                 4000 non-null   int64
#  9   quit                   4000 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 312.6+ KB

# %% [markdown]
# ### 8.3. <a id='toc8_3_'></a>Обработка дубликатов                [&#8593;](#toc0_)

# %%
train2.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Дубликатов нет. Установим столбец `id` в качестве индекса и сразу же отсортируем по нему.

# %%
train2 = train2.set_index('id').sort_index()

# %%
train2.head()
# Out:
#               dept   level workload  employment_years last_year_promo  \
# id
# 100222       sales  junior   medium                 3              no
# 100459  purchasing  junior   medium                 3              no
# 100469   marketing  junior   medium                 1              no
# 100601  technology  middle     high                 4              no
# 100858       sales  junior   medium                 2              no
#
#        last_year_violations  supervisor_evaluation  salary quit
# id
# 100222                   no                      2   20400  yes
# 100459                   no                      3   21600  yes
# 100469                   no                      4   28800   no
# 100601                   no                      4   68400   no
# 100858                   no                      4   25200  yes

# %% [markdown]
# Проверим, не появились ли новые полные дубликаты после удаления id.

# %%
train2.duplicated().sum()
# Out:
# 1413

# %%
train2 = train2.drop_duplicates()

# %%
train2.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### 8.4. <a id='toc8_4_'></a>Проверка пропусков                [&#8593;](#toc0_)

# %%
print_table_about_nans(train2)
# Out:
# +-----------------------+----------------------+
# |        Feature        | Missing values count |
# +-----------------------+----------------------+
# |          dept         |      0 (0.00%)       |
# |         level         |      0 (0.00%)       |
# |        workload       |      0 (0.00%)       |
# |    employment_years   |      0 (0.00%)       |
# |    last_year_promo    |      0 (0.00%)       |
# |  last_year_violations |      0 (0.00%)       |
# | supervisor_evaluation |      0 (0.00%)       |
# |         salary        |      0 (0.00%)       |
# |          quit         |      0 (0.00%)       |
# +-----------------------+----------------------+

# %% [markdown]
# ### 8.5. <a id='toc8_5_'></a>Выделение целевого признака                [&#8593;](#toc0_)

# %%
target = 'quit'

X_train2 = train2.drop(target, axis=1)
y_train2 = train2[target]

# %% [markdown]
# ### 8.6. <a id='toc8_6_'></a>Кодирование целевого признака                [&#8593;](#toc0_)

# %%
y_train2[:5]
# Out:
# id
# 100222    yes
# 100459    yes
# 100469     no
# 100601     no
# 100858    yes
# Name: quit, dtype: object

# %%
label_encoder = LabelEncoder()
y_train2 = label_encoder.fit_transform(y_train2)

# %%
y_train2[:5]
# Out:
# array([1, 1, 0, 0, 1])

# %% [markdown]
# ### 8.7. <a id='toc8_7_'></a>Изучение столбцов          [&#8593;](#toc0_)

# %% [markdown]
# #### 8.7.1. <a id='toc8_7_1_'></a>Столбец `dept`          [&#8593;](#toc0_)

# %%
X_train2['dept'].value_counts()
# Out:
# dept
# sales         805
# technology    581
# purchasing    430
# marketing     423
# hr            348
# Name: count, dtype: int64

# %%
plot_pie_chart(X_train2['dept'])

# %% [markdown]
# #### 8.7.2. <a id='toc8_7_2_'></a>Столбец `level`          [&#8593;](#toc0_)

# %%
X_train2['level'].value_counts()
# Out:
# level
# middle    1282
# junior     958
# sinior     347
# Name: count, dtype: int64

# %%
plot_pie_chart(X_train2['level'])

# %% [markdown]
# #### 8.7.3. <a id='toc8_7_3_'></a>Столбец `workload`          [&#8593;](#toc0_)

# %%
X_train2['workload'].value_counts()
# Out:
# workload
# medium    1244
# low        746
# high       597
# Name: count, dtype: int64

# %%
plot_pie_chart(X_train2['workload'])

# %% [markdown]
# #### 8.7.4. <a id='toc8_7_4_'></a>Столбец `employment_years`          [&#8593;](#toc0_)

# %%
X_train2['employment_years'].value_counts()
# Out:
# employment_years
# 1     451
# 2     422
# 3     329
# 4     311
# 5     280
# 6     224
# 7     220
# 8     146
# 9     118
# 10     86
# Name: count, dtype: int64

# %%
draw_plots_about_column(X_train2, 'employment_years', 'employment_years', 10)

# %% [markdown]
# #### 8.7.5. <a id='toc8_7_5_'></a>Столбец `last_year_promo`          [&#8593;](#toc0_)

# %%
X_train2['last_year_promo'].value_counts()
# Out:
# last_year_promo
# no     2476
# yes     111
# Name: count, dtype: int64

# %%
plot_pie_chart(X_train2['last_year_promo'])

# %% [markdown]
# #### 8.7.6. <a id='toc8_7_6_'></a>Столбец `last_year_violations`          [&#8593;](#toc0_)

# %%
X_train2['last_year_violations'].value_counts()
# Out:
# last_year_violations
# no     2111
# yes     476
# Name: count, dtype: int64

# %%
plot_pie_chart(X_train2['last_year_violations'])

# %% [markdown]
# #### 8.7.7. <a id='toc8_7_7_'></a>Столбец `supervisor_evaluation`          [&#8593;](#toc0_)

# %%
X_train2['supervisor_evaluation'].value_counts()
# Out:
# supervisor_evaluation
# 4    882
# 3    839
# 5    369
# 2    326
# 1    171
# Name: count, dtype: int64

# %%
draw_plots_about_column(X_train2, 'supervisor_evaluation', 'supervisor_evaluation', bins=5)

# %% [markdown]
# #### 8.7.8. <a id='toc8_7_8_'></a>Столбец `salary`          [&#8593;](#toc0_)

# %%
draw_plots_about_column(X_train2, 'salary', 'salary')

# %% [markdown]
# #### 8.7.9. <a id='toc8_7_9_'></a>Столбец `quit`          [&#8593;](#toc0_)

# %%
plot_pie_chart(pd.Series(y_train2, name='quit'))

# %% [markdown]
# ### 8.8. <a id='toc8_8_'></a>Выводы по датасету          [&#8593;](#toc0_)

# %% [markdown]
# Данный датасет очень похож на тренировочный датасет первой задачи. Целевой признак несбалансирован - наблюдений класса `0` в 2.5 раза больше, чем класса `1`. Датасет не имеет полных дубликатов и пропусков.
#
# Целевой признак был закодирован с помощью `LabelEncoder` для дальнейшего использования в моделях МО.

# %% [markdown]
# ## 9. <a id='toc9_'></a>Датасет `y_test2` (test_target_quit.csv)                [&#8593;](#toc0_)

# %% [markdown]
# ### 9.1. <a id='toc9_1_'></a>Загрузка                [&#8593;](#toc0_)

# %%
# data is not presented due to copyright
y_test2 = get_dataframe(['data/y_test2.csv'])

# %%
y_test2.head()
# Out:
#        id quit
# 0  999029  yes
# 1  372846   no
# 2  726767   no
# 3  490105   no
# 4  416898  yes

# %% [markdown]
# ### 9.2. <a id='toc9_2_'></a>Проверка типов данных                [&#8593;](#toc0_)

# %%
y_test2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      2000 non-null   int64
#  1   quit    2000 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 31.4+ KB

# %% [markdown]
# ### 9.3. <a id='toc9_3_'></a>Обработка дубликатов                [&#8593;](#toc0_)

# %%
y_test2.duplicated().sum()
# Out:
# 0

# %%
y_test2 = y_test2.set_index('id').sort_index()['quit']
y_test2[:5]
# Out:
# id
# 100298    no
# 100480    no
# 100503    no
# 100610    no
# 100692    no
# Name: quit, dtype: object

# %% [markdown]
# ### 9.4. <a id='toc9_4_'></a>Проверка пропусков                [&#8593;](#toc0_)

# %%
y_test2.isna().sum()
# Out:
# 0

# %% [markdown]
# ### 9.5. <a id='toc9_5_'></a>Изучение распределения                [&#8593;](#toc0_)

# %%
y_test2.value_counts()
# Out:
# quit
# no     1436
# yes     564
# Name: count, dtype: int64

# %%
plot_pie_chart(y_test2)

# %% [markdown]
# ### 9.6. <a id='toc9_6_'></a>Кодирование целевого признака               [&#8593;](#toc0_)

# %%
y_test2[8:13]
# Out:
# id
# 102222     no
# 102320     no
# 103221    yes
# 103278     no
# 103342    yes
# Name: quit, dtype: object

# %%
y_test2 = pd.Series(label_encoder.transform(y_test2), index=y_test2.index)

# %%
y_test2[8:13]
# Out:
# id
# 102222    0
# 102320    0
# 103221    1
# 103278    0
# 103342    1
# dtype: int64

# %% [markdown]
# ### 9.7. <a id='toc9_7_'></a>Выводы по датасету         [&#8593;](#toc0_)

# %% [markdown]
# Распределение целевого признака в тестовом датасете такое же, как и в тренировочном. Датасет после проверок был также преобразован к серии (pd.Series) для удобства дальнейшего использования.

# %% [markdown]
# ## 10. <a id='toc10_'></a>Исследовательский анализ данных                [&#8593;](#toc0_)

# %% [markdown]
# ### 10.1. <a id='toc10_1_'></a>Изучение        [&#8593;](#toc0_)

# %%
_mask = y_train2 == 1
quit = X_train2[_mask]
not_quit = X_train2[~_mask]

len(quit), len(not_quit)
# Out:
# (655, 1932)

# %%
info = pd.DataFrame(columns=['quit', 'not_quit'])
columns = quit.select_dtypes(include='number')
for col in columns:
    info.loc[col + '__mean'] = [quit[col].mean(), not_quit[col].mean()]
    info.loc[col + '__median'] = [quit[col].median(), not_quit[col].median()]

info.T
# Out:
#           employment_years__mean  employment_years__median  \
# quit                        2.16                      2.00
# not_quit                    4.91                      5.00
#
#           supervisor_evaluation__mean  supervisor_evaluation__median  \
# quit                             2.96                           3.00
# not_quit                         3.51                           4.00
#
#           salary__mean  salary__median
# quit          25767.94        24000.00
# not_quit      40952.17        39000.00

# %% [markdown]
# ---

# %%
draw_pair_pie_plot(quit, 'quit', not_quit, 'not_quit', 'dept')

# %%
draw_pair_pie_plot(quit, 'quit', not_quit, 'not_quit', 'level')

# %%
draw_pair_pie_plot(quit, 'quit', not_quit, 'not_quit', 'workload')

# %%
draw_pair_pie_plot(quit, 'quit', not_quit, 'not_quit', 'last_year_promo')

# %%
draw_pair_pie_plot(quit, 'quit', not_quit, 'not_quit', 'last_year_violations')

# %% [markdown]
# ---

# %%
job_satisfaction_rate_for_test = grid.predict(X_test)

# %%
_mask = y_test2 == 1
quit = job_satisfaction_rate_for_test[_mask]
not_quit = job_satisfaction_rate_for_test[~_mask]

# %%
print(f'   Средний уровень удовлетворенности сотрудников, кто ушел = {quit.mean():.2f}')
print(f'Средний уровень удовлетворенности сотрудников, кто НЕ ушел = {not_quit.mean():.2f}')
# Out:
#    Средний уровень удовлетворенности сотрудников, кто ушел = 0.40
# Средний уровень удовлетворенности сотрудников, кто НЕ ушел = 0.61

# %%
plt.hist(quit, alpha=0.5, label='quit', weights=np.ones_like(quit) / len(quit))
plt.hist(not_quit, alpha=0.5, label='not quit', weights=np.ones_like(not_quit) / len(not_quit))
plt.title('Гистограмма распределения уровня удовлетворенности\nушедших и неушедших сотрудников')
plt.xlabel('Уровень удовлетворенности')
plt.ylabel('Относительная частота встречаемости')
plt.legend()
plt.show()

# %% [markdown]
# ### 10.2. <a id='toc10_2_'></a>Вывод       [&#8593;](#toc0_)

# %% [markdown]
# "Портрет уволившегося сотрудника" может быть такой:
# - начинающий специалист (junior уровень)
# - в компании работает 1-2 года
# - средняя оценка от руководителя около 3 баллов
# - зарплата 23-24 тысячи
#
#
# Гипотеза подтвердилась: признак `job_satisfaction_rate` действительно влияет на то, уволится ли сотрудник.

# %% [markdown]
# ## 11. <a id='toc11_'></a>Добавление нового признака       [&#8593;](#toc0_)

# %%
X_train2.head()
# Out:
#               dept   level workload  employment_years last_year_promo  \
# id
# 100222       sales  junior   medium                 3              no
# 100459  purchasing  junior   medium                 3              no
# 100469   marketing  junior   medium                 1              no
# 100601  technology  middle     high                 4              no
# 100858       sales  junior   medium                 2              no
#
#        last_year_violations  supervisor_evaluation  salary
# id
# 100222                   no                      2   20400
# 100459                   no                      3   21600
# 100469                   no                      4   28800
# 100601                   no                      4   68400
# 100858                   no                      4   25200

# %%
X_train2['job_satisfaction_rate'] = grid.predict(X_train2)

# %%
X_train2.head()
# Out:
#               dept   level workload  employment_years last_year_promo  \
# id
# 100222       sales  junior   medium                 3              no
# 100459  purchasing  junior   medium                 3              no
# 100469   marketing  junior   medium                 1              no
# 100601  technology  middle     high                 4              no
# 100858       sales  junior   medium                 2              no
#
#        last_year_violations  supervisor_evaluation  salary  \
# id
# 100222                   no                      2   20400
# 100459                   no                      3   21600
# 100469                   no                      4   28800
# 100601                   no                      4   68400
# 100858                   no                      4   25200
#
#         job_satisfaction_rate
# id
# 100222                   0.34
# 100459                   0.33
# 100469                   0.64
# 100601                   0.66
# ...

# %% [markdown]
# ## 12. <a id='toc12_'></a>Пайплайны и модели       [&#8593;](#toc0_)

# %% [markdown]
# ### 12.1. <a id='toc12_1_'></a>Пайплайны  [&#8593;](#toc0_)

# %%
target = 'quit'

num_cols = [
    'employment_years',
    'supervisor_evaluation',
    'salary',
    'job_satisfaction_rate'
]

ohe_cols = [
    'dept'
]

ord_cols = [
    'level',
    'workload',
    'last_year_promo',
    'last_year_violations'
]

# %%
data_preprocessor2 = ColumnTransformer(
    [
        ('ohe', ohe_pipeline, ohe_cols),
        ('ord', ord_pipeline, ord_cols),
        ('num', MinMaxScaler(), num_cols)
    ],
    remainder='passthrough'
)

# %%
final_pipeline2 = Pipeline(
    [
        ('preprocessor', data_preprocessor2),
        ('models', DecisionTreeClassifier(random_state=RANDOM_STATE))
    ]
)

# %%
final_pipeline2
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('SimpleImputer_before_ohe_1',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('SimpleImputer_before_ohe_2',
#                                                                    SimpleImputer(missing_values=' ',
#                                                                                  strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
# ...

# %% [markdown]
# ### 12.2. <a id='toc12_2_'></a>Модели  [&#8593;](#toc0_)

# %%
param_grid2 = [
    {
        'models': [DecisionTreeClassifier(random_state=RANDOM_STATE)],
        'models__max_depth': range(2,  5),
        'models__max_features': range(2, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    },
    {
        'models': [KNeighborsClassifier(n_jobs=-1)],
        'models__n_neighbors': range(2, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    },
    {
        'models': [LogisticRegression(penalty='l1', solver='liblinear')],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    },
    {
        'models': [SVC(random_state=RANDOM_STATE)],
        'models__C': [0.01, 0.1, 1, 10, 100],
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    },
    {
        'models': [RandomForestClassifier(n_jobs=-1, random_state=RANDOM_STATE)],
        'models__n_estimators': [100, 300, 500],
        'models__min_samples_split': range(2, 11),
        'models__min_samples_leaf': range(1, 11),
        'models__max_depth': range(2, 11),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    }
]

# %% [markdown]
# ---

# %%
grid2 = RandomizedSearchCV(
    final_pipeline2,
    param_distributions=param_grid2,
    n_iter=100,
    scoring='roc_auc',
    n_jobs=-1,
    cv=5,
    random_state=RANDOM_STATE
)

# %%
# %%time

grid2.fit(X_train2, y_train2)
print()
# Out:
# CPU times: user 1.32 s, sys: 229 ms, total: 1.55 s
# Wall time: 46.5 s

# %%
round(grid2.best_score_, 4)
# Out:
# 0.9196

# %%
grid2.best_estimator_
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('SimpleImputer_before_ohe_1',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('SimpleImputer_before_ohe_2',
#                                                                    SimpleImputer(missing_values=' ',
#                                                                                  strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
# ...

# %%
pd.DataFrame(grid2.cv_results_)\
    [['rank_test_score', 'param_models', 'mean_test_score', 'params']]\
    .sort_values(by='rank_test_score')\
    .head()
# Out:
#     rank_test_score                                        param_models  \
# 21                1  RandomForestClassifier(n_jobs=-1, random_state=27)
# 56                2  RandomForestClassifier(n_jobs=-1, random_state=27)
# 46                3  RandomForestClassifier(n_jobs=-1, random_state=27)
# 40                4  RandomForestClassifier(n_jobs=-1, random_state=27)
# 66                5  RandomForestClassifier(n_jobs=-1, random_state=27)
#
#     mean_test_score  \
# 21             0.92
# 56             0.92
# 46             0.92
# 40             0.92
# 66             0.92
#
#                                                                                                                                                                                                                        params
# ...

# %% [markdown]
# ---

# %%
X_test2 = X_test.copy()

# %%
X_test2['job_satisfaction_rate'] = grid.predict(X_test)

# %%
y_pred2 = grid2.predict_proba(X_test2)[:, 1]
round(roc_auc_score(y_test2, y_pred2), 4)
# Out:
# 0.9239

# %% [markdown]
# ### 12.3. <a id='toc12_3_'></a>Вывод   [&#8593;](#toc0_)

# %% [markdown]
# Признак, предсказанный в рамках 1 задачи, действительно влияет на то, уволится ли сотрудник из компании. Поэтому данный признак был добавлен в датасет при обучении.
#
# Лучше всего себя показал RandomForest. Результат составил `0.9239`, что больше порога в `0.91` по метрике ROC_AUC. Однако попробуем провести различные преобразования, чтобы улучшить качество.

# %% [markdown]
# ## 13. <a id='toc13_'></a>Улучшение модели      [&#8593;](#toc0_)

# %% [markdown]
# ### 13.1. <a id='toc13_1_'></a>Удаление столбца    [&#8593;](#toc0_)

# %%
best_model2 = grid2.best_estimator_.named_steps['models']

# %%
X_train2_transformed = grid2.best_estimator_.named_steps['preprocessor'].transform(X_train2)

# %%
features_names = grid2.best_estimator_.named_steps['preprocessor'].get_feature_names_out()

# %%
result = permutation_importance(
    best_model2,
    X_train2_transformed,
    y_train2,
    scoring='roc_auc')

feature_importance = pd.DataFrame({'Feature': features_names, 'Importance': result['importances_mean']})
feature_importance = feature_importance.sort_values('Importance', ascending=True)
sns.set_style('white')
feature_importance.plot(x='Feature', y='Importance', kind='barh', figsize=(10, 6));
plt.legend();

# %%
df = X_train2.copy()
df['quit'] = y_train2

plt.figure(figsize=(10, 5))
sns.heatmap(df.phik_matrix(interval_cols=num_cols + [target]),
            cmap='Greens',
            annot=True,
            fmt='.2f');

plt.title(r'$phi_k$ корреляция между всеми признаками', fontsize=18);

# %% [markdown]
# Результаты анализа разницы между ушедшими и оставшимися сотрудниками, а также phik корреляция говорит о том, что департамент, котором работает сотрудник, не влияет на то, уйдет он или нет. Удалим данный столбец и обновим пайплайн.

# %%
X_train2.columns
# Out:
# Index(['dept', 'level', 'workload', 'employment_years', 'last_year_promo',
#        'last_year_violations', 'supervisor_evaluation', 'salary',
#        'job_satisfaction_rate'],
#       dtype='object')

# %%
X_train2 = X_train2.drop('dept', axis=1)

# %%
X_train2.columns
# Out:
# Index(['level', 'workload', 'employment_years', 'last_year_promo',
#        'last_year_violations', 'supervisor_evaluation', 'salary',
#        'job_satisfaction_rate'],
#       dtype='object')

# %% [markdown]
# Адаптируем пайплайн с учетом изменений.

# %%
data_preprocessor2 = ColumnTransformer(
    [
        ('ord', ord_pipeline, ord_cols),
        ('num', MinMaxScaler(), num_cols)
    ],
    remainder='passthrough'
)

# %%
final_pipeline2 = Pipeline(
    [
        ('preprocessor', data_preprocessor2),
        ('models', DecisionTreeClassifier(random_state=RANDOM_STATE))
    ]
)

# %%
final_pipeline2
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ord',
#                                                   Pipeline(steps=[('SimpleImputer_before_ord_1',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('SimpleImputer_before_ord_2',
#                                                                    SimpleImputer(missing_values=' ',
#                                                                                  strategy='most_frequent')),
#                                                                   ('ord',
#                                                                    OrdinalEncoder(categories=[['junior',
#                                                                                                'middle',
# ...

# %%
grid2 = RandomizedSearchCV(
    final_pipeline2,
    param_distributions=param_grid2,
    n_iter=100,
    scoring='roc_auc',
    cv=5,
    random_state=RANDOM_STATE
)

# %%
# %%time
grid2.fit(X_train2, y_train2);
# Out:
# CPU times: user 3min 42s, sys: 1min 17s, total: 5min
# Wall time: 2min 57s

# %%
round(grid2.best_score_, 4)
# Out:
# 0.9213

# %% [markdown]
# Удалим данный столбец из тестового датасета.

# %%
X_test2.columns
# Out:
# Index(['dept', 'level', 'workload', 'employment_years', 'last_year_promo',
#        'last_year_violations', 'supervisor_evaluation', 'salary',
#        'job_satisfaction_rate'],
#       dtype='object')

# %%
X_test2 = X_test2.drop('dept', axis=1)

# %%
X_test2.columns
# Out:
# Index(['level', 'workload', 'employment_years', 'last_year_promo',
#        'last_year_violations', 'supervisor_evaluation', 'salary',
#        'job_satisfaction_rate'],
#       dtype='object')

# %%
y_pred2 = grid2.predict_proba(X_test2)[:, 1]
round(roc_auc_score(y_test2, y_pred2), 4)
# Out:
# 0.9247

# %% [markdown]
# Качество на тренировочной выборке упало, но чуть выросло на тестовой (0.9239 -> 0.9247)

# %% [markdown]
# ### 13.2. <a id='toc13_2_'></a>ADASYN      [&#8593;](#toc0_)

# %%
pd.Series(y_train2).value_counts()
# Out:
# 0    1932
# 1     655
# Name: count, dtype: int64

# %%
temp_preprocessor: ColumnTransformer = grid2.best_estimator_.named_steps['preprocessor']
X_train2_transformed = temp_preprocessor.transform(X_train2)
X_test2_transformed = temp_preprocessor.transform(X_test2)

# %%
sampler = ADASYN(random_state=RANDOM_STATE)
X_train2_resampled, y_train2_resampled = sampler.fit_resample(X_train2_transformed, y_train2)

# %%
pd.Series(y_train2_resampled).value_counts()
# Out:
# 1    1947
# 0    1932
# Name: count, dtype: int64

# %% [markdown]
# Попробуем обучить модель снова.

# %%
best_model2.fit(X_train2_resampled, y_train2_resampled);

# %%
y_pred2 = best_model2.predict_proba(X_test2_transformed)[:, 1]
round(roc_auc_score(y_test2, y_pred2), 4)
# Out:
# 0.9208

# %% [markdown]
# Оверсемплинг не дал желаемого результата.

# %% [markdown]
# ### 13.3. <a id='toc13_3_'></a>SMOTE      [&#8593;](#toc0_)

# %% [markdown]
# Попробуем использовать другую технику оверсемплинга.

# %%
sampler = SMOTE(
    random_state=RANDOM_STATE,
    k_neighbors=10)

# %%
pd.Series(y_train2).value_counts()
# Out:
# 0    1932
# 1     655
# Name: count, dtype: int64

# %%
X_train2_resampled, y_train2_resampled = sampler.fit_resample(X_train2_transformed, y_train2)

# %%
pd.Series(y_train2_resampled).value_counts()
# Out:
# 1    1932
# 0    1932
# Name: count, dtype: int64

# %% [markdown]
# Пробуем обучить модель.

# %%
best_model2.fit(X_train2_resampled, y_train2_resampled);

# %%
y_pred2 = best_model2.predict_proba(X_test2_transformed)[:, 1]
round(roc_auc_score(y_test2, y_pred2), 4)
# Out:
# 0.9235

# %% [markdown]
# Метрика чуть лучше, чем при использовании ADASYN. Однако техники оверсемплинга  привели лишь к ухудшению метрики на тестовом датасете. Возможно, это связано с особенностью `roc_auc`. Возможно, `f1` показала бы другой результат.

# %% [markdown]
# ### 13.4. <a id='toc13_4_'></a>Вывод     [&#8593;](#toc0_)

# %% [markdown]
# ## 14. <a id='toc14_'></a>Общий вывод      [&#8593;](#toc0_)

# %% [markdown]
# В рамках данного проекта было поставлено 2 задачи:
# 1) предсказание уровня удовлетворенности сотрудника
# 2) предсказание увольнения сотрудника из компании
#
# Подготовка датасетов состояла из большого количества шагов: проверка типов данных, проверка на дубликаты и пропуски, а также изучение распределений всех признаков.
#
# Далее были составлены пайплайны для обработки столбцов различных типов (числовые, категориальные номинальные и категориальные порядковые). Все пайплайны по обработке были собраны в ColumnTransformer и объединены с моделью в финальный пайплайн.
#
# С помощью инструменты RandomizedSearchCV был выбран оптимальный метод подготовки числовых данных, модель и гиперпараметры для нее.
#
# **Задача 1**
# Лучше всего себя показал RandomForest, что позволило получить SMAPE метрику `12.22` на тестовом датасете. Это меньше максимально допустимой метрики в `15`. Анализ остатков также не выявил проблем модели. Следовательно, модель неплохо показывает себя.
#
# *Выводы:*
# - Как и показала phik корреляция, признак `supervisor_evaluation` (оценка руководителя) имеет высокое влияние на целевой признак. Чем выше оценка - тем больше сотрудник удовлетворен работой. И наоборот: если оценка руководителя низкая - это показатель низкой удовлетстворенности сотрудника работой. Причем здесь, скорее всего, прослеживается обратная причинно-следственная связь. Если сотрудник не удовлетворен работой -> он не очень ответственно относится к своим задачам -> руководитель ставит ему низкую оценку.
# - Количество лет, которые сотрудник проработал в компании (признак `employment_years`) позитивно влияет на его удовлетворенность. Чем больше лет сотрудник работает в этой компании, тем более он удовлетворен. А вот сотрудники, кто работает в компании не так давно менее удовлетворены работой. Возможно, компании стоит присмотреться к новичкам. Например, пересмотреть их процесс адаптации, длительность испытательного срока и т.д.
# - Но парадоксально с предыдущим выводом имеет следующий факт. По большей части работой удовлетворены начинающие специалисты. И чем выше уровень специалиста (признак `level`), тем ниже уровень удовлетворенности. Компании стоит пересмотреть "плюшки" для опытных специалистов (особенно senior уровня).
# - Зарплата (столбец `salary`) имеет ожидаемо напрямую влияет на уровень удовлетворенности.
# - Уровень нагрузки (признак `workload`) подтверждает вывод № 3. Чем выше нагрузка - тем меньший уровень удовлетворенности у сотрудника. Возможно, компании стоит пересмотреть ЗП у сотрудников в высокой нагрузкой и/или награду за переработки.
# - Наличие нарушений в трудовом договоре (столбец `last_year_violations`) также напрямую влияет на целевой признак и скорее всего также (как и для признака `supervisor_evaluation`) имеет обратную причинно-следственную связь. Ведь если сотрудник нарушал трудовой друговор, значит его что-то не устраивает. Отсюда и невысокая удовлетворенность.
#
# ---
#
# **Задача 2**
# Здесь также лучшей моделью оказался RandomForest. ROC_AUC на тестовой выборе составил `0.9239` до удаления столбца `dept` и `0.9247` после удаления. Методы оверсемплинга (ADASYN и SMOTE) не привели к улучшению метрики на тестовых данных и показали ROC_AUC `0.9208` и `0.9235` соответственно.
#
# Также был составлен "Портрет уволившегося сотрудника":
# - начинающий специалист (junior уровень)
# - в компании работает 1-2 года
# - средняя оценка от руководителя около 3 баллов
# - зарплата 23-24 тысячи
